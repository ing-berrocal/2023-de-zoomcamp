# %%
import pandas as pd
from fastparquet import ParquetFile as pf

# %% [markdown]
# ### Descarga data
# wget "https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2022-01.parquet"

# %% [markdown]
# ### Debido a cambio en el formato de data, se instala el paquete para leer el formato
# ### apache paquefile

# %%
pfData = pf('../data/yellow_tripdata_2021-01.parquet')
data = pfData.to_pandas()

# %%
data.head(101)
# Out:
#      VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0           1  2021-01-01 00:30:10   2021-01-01 00:36:12              1.0
# 1           1  2021-01-01 00:51:20   2021-01-01 00:52:19              1.0
# 2           1  2021-01-01 00:43:30   2021-01-01 01:11:06              1.0
# 3           1  2021-01-01 00:15:48   2021-01-01 00:31:01              0.0
# 4           2  2021-01-01 00:31:49   2021-01-01 00:48:21              1.0
# ..        ...                  ...                   ...              ...
# 96          2  2021-01-01 00:23:29   2021-01-01 00:35:03              2.0
# 97          2  2021-01-01 00:46:17   2021-01-01 00:54:25              2.0
# 98          2  2021-01-01 00:28:16   2021-01-01 00:51:44              1.0
# 99          2  2021-01-01 00:42:35   2021-01-01 00:54:41              3.0
# 100         2  2021-01-01 00:32:26   2021-01-01 00:38:05              1.0
#
#      trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# ...

# %%
data.dtypes
# Out:
# VendorID                          int64
# tpep_pickup_datetime     datetime64[ns]
# tpep_dropoff_datetime    datetime64[ns]
# passenger_count                 float64
# trip_distance                   float64
# RatecodeID                      float64
# store_and_fwd_flag               object
# PULocationID                      int64
# DOLocationID                      int64
# payment_type                      int64
# fare_amount                     float64
# extra                           float64
# mta_tax                         float64
# tip_amount                      float64
# tolls_amount                    float64
# improvement_surcharge           float64
# total_amount                    float64
# congestion_surcharge            float64
# airport_fee                     float64
# dtype: object

# %%
data.size,data.shape
# Out:
# (26025611, (1369769, 19))

# %%
df = data
df.columns = df.columns = [ x.lower() for x in df.columns]

# %%
df.head()
# Out:
#    vendorid tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2021-01-01 00:30:10   2021-01-01 00:36:12              1.0
# 1         1  2021-01-01 00:51:20   2021-01-01 00:52:19              1.0
# 2         1  2021-01-01 00:43:30   2021-01-01 01:11:06              1.0
# 3         1  2021-01-01 00:15:48   2021-01-01 00:31:01              0.0
# 4         2  2021-01-01 00:31:49   2021-01-01 00:48:21              1.0
#
#    trip_distance  ratecodeid store_and_fwd_flag  pulocationid  dolocationid  \
# 0           2.10         1.0                  N           142            43
# 1           0.20         1.0                  N           238           151
# 2          14.70         1.0                  N           132           165
# 3          10.60         1.0                  N           138           132
# 4           4.94         1.0                  N            68            33
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
df.to_csv('../data/yellow_tripdata_2021-01.csv',index=False)

# %%
df = pd.read_csv('../data/yellow_tripdata_2021-01_100.csv')
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_28960\2204177997.py:1: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../data/yellow_tripdata_2021-01_100.csv')

# %%
df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2021-01-01 00:30:10   2021-01-01 00:36:12              1.0
# 1         1  2021-01-01 00:51:20   2021-01-01 00:52:19              1.0
# 2         1  2021-01-01 00:43:30   2021-01-01 01:11:06              1.0
# 3         1  2021-01-01 00:15:48   2021-01-01 00:31:01              0.0
# 4         2  2021-01-01 00:31:49   2021-01-01 00:48:21              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           2.10         1.0                  N           142            43
# 1           0.20         1.0                  N           238           151
# 2          14.70         1.0                  N           132           165
# 3          10.60         1.0                  N           138           132
# 4           4.94         1.0                  N            68            33
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...
